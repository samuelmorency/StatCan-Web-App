# %%
import pandas as pd
import numpy as np
import geopandas as gpd
#%pip install openpyxl
#%pip install pyxlsb
#%pip install pyjanitor
import janitor
import pyxlsb
import openpyxl

# %%
gen_df_19_22 = pd.read_excel("IIC_CSBP_D3_Enrollments-Graduates_2019-2022.xlsb", sheet_name="GEN")
#imm_df = pd.read_excel("IIC_CSBP_D3_Enrollments-Graduates_2019-2022.xlsx", sheet_name="IMM")
gen_df_19_22
# Out:
#                      ISCED Level of Education Credential Type  CIP6 Code  \
# 0       Post-secondary non-tertiary education     Certificate    12.0407
# 1       Post-secondary non-tertiary education     Certificate    12.0500
# 2       Post-secondary non-tertiary education     Certificate    12.0501
# 3       Post-secondary non-tertiary education     Certificate    19.0709
# 4       Post-secondary non-tertiary education     Certificate    21.0101
# ...                                       ...             ...        ...
# 369193  Post-secondary non-tertiary education     Certificate    15.0901
# 369194  Post-secondary non-tertiary education  Not applicable    15.0901
# 369195         Short-cycle tertiary education         Diploma    15.0507
# 369196         Short-cycle tertiary education         Diploma    15.1202
# 369197         Short-cycle tertiary education         Diploma    15.0507
#
#                                                  CIP Name  PR code  \
# 0                    Hair styling/stylist and hair design       10
# 1       Cooking and related culinary arts, general (ex...       10
# 2                Baking and pastry arts/baker/pastry chef       10
# 3                           Child care provider/assistant       10
# 4       Pre-technology education/pre-industrial arts p...       10
# ...                                                   ...      ...
# 369193                       Mining technology/technician       62
# 369194                       Mining technology/technician       62
# 369195  Environmental engineering technology/environme...       62
# 369196    Computer technology/computer systems technology       62
# 369197  Environmental engineering technology/environme...       62
#
#             PRdguid      Province or Territory Academic Year Value  \
# 0       2021A000210  Newfoundland and Labrador     2019_2020    ..
# 1       2021A000210  Newfoundland and Labrador     2019_2020    42
# 2       2021A000210  Newfoundland and Labrador     2019_2020     3
# 3       2021A000210  Newfoundland and Labrador     2019_2020     3
# 4       2021A000210  Newfoundland and Labrador     2019_2020     9
# ...             ...                        ...           ...   ...
# 369193  2021A000262                    Nunavut     2021_2022    27
# 369194  2021A000262                    Nunavut     2021_2022    66
# 369195  2021A000262                    Nunavut     2021_2022     0
# 369196  2021A000262                    Nunavut     2021_2022    ..
# 369197  2021A000262                    Nunavut     2021_2022     3
#
#        Enrollment Type            Source Sheet             Institution CMAuid  \
# 0                  GEN   BHASE_GEN_ENROLL_PROV                     NaN    NaN
# 1                  GEN   BHASE_GEN_ENROLL_PROV                     NaN    NaN
# 2                  GEN   BHASE_GEN_ENROLL_PROV                     NaN    NaN
# 3                  GEN   BHASE_GEN_ENROLL_PROV                     NaN    NaN
# 4                  GEN   BHASE_GEN_ENROLL_PROV                     NaN    NaN
# ...                ...                     ...                     ...    ...
# 369193             GEN  STEM_GEN_ENROLL_NONCMA  Nunavut Arctic College      0
# 369194             GEN  STEM_GEN_ENROLL_NONCMA  Nunavut Arctic College      0
# 369195             GEN  STEM_GEN_ENROLL_NONCMA  Nunavut Arctic College      0
# 369196             GEN  STEM_GEN_ENROLL_NONCMA  Nunavut Arctic College      0
# 369197             GEN  STEM_GEN_ENROLL_NONCMA  Nunavut Arctic College      0
#
#                                                   CMAname     CSDuid  CSDname
# 0                                                     NaN        NaN      NaN
# 1                                                     NaN        NaN      NaN
# 2                                                     NaN        NaN      NaN
# 3                                                     NaN        NaN      NaN
# 4                                                     NaN        NaN      NaN
# ...                                                   ...        ...      ...
# 369193  Territories (outside CAs, Nvt.) / Territoires ...  6204003.0  Iqaluit
# 369194  Territories (outside CAs, Nvt.) / Territoires ...  6204003.0  Iqaluit
# 369195  Territories (outside CAs, Nvt.) / Territoires ...  6204003.0  Iqaluit
# 369196  Territories (outside CAs, Nvt.) / Territoires ...  6204003.0  Iqaluit
# 369197  Territories (outside CAs, Nvt.) / Territoires ...  6204003.0  Iqaluit
#
# [369198 rows x 16 columns]

# %%
gen_df_22_23 = pd.read_excel("IIC_CSBP_D3_Enrollments-Graduates_2022-2023.xlsb", sheet_name="Gender")
gen_df_22_23
# Out:
#         ISCED Level of Education                    Credential Type  \
# 0       Bachelor’s or equivalent  Degree  (includes applied degree)
# 1       Bachelor’s or equivalent  Degree  (includes applied degree)
# 2       Bachelor’s or equivalent  Degree  (includes applied degree)
# 3       Bachelor’s or equivalent  Degree  (includes applied degree)
# 4       Bachelor’s or equivalent  Degree  (includes applied degree)
# ...                          ...                                ...
# 112751  Bachelor’s or equivalent  Degree  (includes applied degree)
# 112752  Bachelor’s or equivalent  Degree  (includes applied degree)
# 112753  Bachelor’s or equivalent  Degree  (includes applied degree)
# 112754  Bachelor’s or equivalent  Degree  (includes applied degree)
# 112755    Master’s or equivalent  Degree  (includes applied degree)
#
#         CIP6 Code                                         CIP Name  \
# 0         45.9999                           Social sciences, other
# 1         13.1202                Elementary education and teaching
# 2         50.0901                                   Music, general
# 3         45.1101                               Sociology, general
# 4         19.0504                                  Human nutrition
# ...           ...                                              ...
# 112751    44.0401                   Public administration, general
# 112752    44.0701                             Social work, general
# 112753    52.0201  Business administration and management, general
# 112754    13.0101                               Education, general
# 112755    44.0401                   Public administration, general
#
#        Province or Territory  \
# 0                Nova Scotia
# 1                Nova Scotia
# 2                Nova Scotia
# 3                Nova Scotia
# 4                Nova Scotia
# ...                      ...
# 112751       Yukon Territory
# 112752       Yukon Territory
# 112753       Yukon Territory
# 112754       Yukon Territory
# 112755       Yukon Territory
#
#                                               Institution     CSDname  Value  \
# 0       St. Francis Xavier University - Parent Institu...  Antigonish      3
# 1       St. Francis Xavier University - Parent Institu...  Antigonish      0
# 2       St. Francis Xavier University - Parent Institu...  Antigonish      3
# 3       St. Francis Xavier University - Parent Institu...  Antigonish     36
# 4       St. Francis Xavier University - Parent Institu...  Antigonish     66
# ...                                                   ...         ...    ...
# 112751                                                NaN         NaN      0
# 112752                                                NaN         NaN      9
# 112753                                                NaN         NaN      0
# 112754                                                NaN         NaN      9
# 112755                                                NaN         NaN      0
#
#        Academic Year Enrollment Type             Source Sheet CMAname  \
# 0          2022_2023             GEN  BHASE_GEN_ENROLL_NONCMA     NaN
# 1          2022_2023             GEN  BHASE_GEN_ENROLL_NONCMA     NaN
# 2          2022_2023             GEN  BHASE_GEN_ENROLL_NONCMA     NaN
# 3          2022_2023             GEN  BHASE_GEN_ENROLL_NONCMA     NaN
# 4          2022_2023             GEN  BHASE_GEN_ENROLL_NONCMA     NaN
# ...              ...             ...                      ...     ...
# 112751     2022_2023             GEN      BHASE_GEN_GRAD_PROV     NaN
# 112752     2022_2023             GEN      BHASE_GEN_GRAD_PROV     NaN
# 112753     2022_2023             GEN      BHASE_GEN_GRAD_PROV     NaN
# 112754     2022_2023             GEN      BHASE_GEN_GRAD_PROV     NaN
# 112755     2022_2023             GEN      BHASE_GEN_GRAD_PROV     NaN
#
#            CSDuid  CMAuid   PR code      PRdguid
# 0       1214002.0     NaN      12.0  2021A000212
# 1       1214002.0     NaN      12.0  2021A000212
# 2       1214002.0     NaN      12.0  2021A000212
# 3       1214002.0     NaN      12.0  2021A000212
# 4       1214002.0     NaN      12.0  2021A000212
# ...           ...     ...       ...          ...
# 112751        NaN     NaN      60.0  2021A000260
# 112752        NaN     NaN      60.0  2021A000260
# 112753        NaN     NaN      60.0  2021A000260
# 112754        NaN     NaN      60.0  2021A000260
# 112755        NaN     NaN      60.0  2021A000260
#
# [112756 rows x 16 columns]

# %%
gen_df = pd.concat([gen_df_19_22, gen_df_22_23], ignore_index=True)
gen_df
# Out:
#                      ISCED Level of Education  \
# 0       Post-secondary non-tertiary education
# 1       Post-secondary non-tertiary education
# 2       Post-secondary non-tertiary education
# 3       Post-secondary non-tertiary education
# 4       Post-secondary non-tertiary education
# ...                                       ...
# 481949               Bachelor’s or equivalent
# 481950               Bachelor’s or equivalent
# 481951               Bachelor’s or equivalent
# 481952               Bachelor’s or equivalent
# 481953                 Master’s or equivalent
#
#                           Credential Type  CIP6 Code  \
# 0                             Certificate    12.0407
# 1                             Certificate    12.0500
# 2                             Certificate    12.0501
# 3                             Certificate    19.0709
# 4                             Certificate    21.0101
# ...                                   ...        ...
# 481949  Degree  (includes applied degree)    44.0401
# 481950  Degree  (includes applied degree)    44.0701
# 481951  Degree  (includes applied degree)    52.0201
# 481952  Degree  (includes applied degree)    13.0101
# 481953  Degree  (includes applied degree)    44.0401
#
#                                                  CIP Name  PR code  \
# 0                    Hair styling/stylist and hair design       10
# 1       Cooking and related culinary arts, general (ex...       10
# 2                Baking and pastry arts/baker/pastry chef       10
# 3                           Child care provider/assistant       10
# 4       Pre-technology education/pre-industrial arts p...       10
# ...                                                   ...      ...
# 481949                     Public administration, general     60.0
# 481950                               Social work, general     60.0
# 481951    Business administration and management, general     60.0
# 481952                                 Education, general     60.0
# 481953                     Public administration, general     60.0
#
#             PRdguid      Province or Territory Academic Year Value  \
# 0       2021A000210  Newfoundland and Labrador     2019_2020    ..
# 1       2021A000210  Newfoundland and Labrador     2019_2020    42
# 2       2021A000210  Newfoundland and Labrador     2019_2020     3
# 3       2021A000210  Newfoundland and Labrador     2019_2020     3
# 4       2021A000210  Newfoundland and Labrador     2019_2020     9
# ...             ...                        ...           ...   ...
# 481949  2021A000260            Yukon Territory     2022_2023     0
# 481950  2021A000260            Yukon Territory     2022_2023     9
# 481951  2021A000260            Yukon Territory     2022_2023     0
# 481952  2021A000260            Yukon Territory     2022_2023     9
# 481953  2021A000260            Yukon Territory     2022_2023     0
#
#        Enrollment Type           Source Sheet Institution CMAuid CMAname  \
# 0                  GEN  BHASE_GEN_ENROLL_PROV         NaN    NaN     NaN
# 1                  GEN  BHASE_GEN_ENROLL_PROV         NaN    NaN     NaN
# 2                  GEN  BHASE_GEN_ENROLL_PROV         NaN    NaN     NaN
# 3                  GEN  BHASE_GEN_ENROLL_PROV         NaN    NaN     NaN
# 4                  GEN  BHASE_GEN_ENROLL_PROV         NaN    NaN     NaN
# ...                ...                    ...         ...    ...     ...
# 481949             GEN    BHASE_GEN_GRAD_PROV         NaN    NaN     NaN
# 481950             GEN    BHASE_GEN_GRAD_PROV         NaN    NaN     NaN
# 481951             GEN    BHASE_GEN_GRAD_PROV         NaN    NaN     NaN
# 481952             GEN    BHASE_GEN_GRAD_PROV         NaN    NaN     NaN
# 481953             GEN    BHASE_GEN_GRAD_PROV         NaN    NaN     NaN
#
#         CSDuid CSDname
# 0          NaN     NaN
# 1          NaN     NaN
# 2          NaN     NaN
# 3          NaN     NaN
# 4          NaN     NaN
# ...        ...     ...
# 481949     NaN     NaN
# 481950     NaN     NaN
# 481951     NaN     NaN
# 481952     NaN     NaN
# 481953     NaN     NaN
#
# [481954 rows x 16 columns]

# %%
def clean_data(df):
    # Drop columns: 'CIP6 Code', 'Province or Territory' and 4 other columns
    df_clean = (df
          .drop(columns=['CIP6 Code', 'Province or Territory', 'Enrollment Type', 'CMAname', 'CSDname'])
          .rename(columns={'Source Sheet': 'STEM/BHASE',
                           ' PR code': 'PR code',
                           'PRdguid': 'PRDGUID',
                           'CMAuid': 'CMAPUID',
                           'CSDuid': 'CSDUID'})
          .astype({'PR code': 'category', 
                   'ISCED Level of Education': 'category', 
                   'Credential Type': 'category', 
                   'CIP Name': 'category', 
                   'PRDGUID': 'category', 
                   'Academic Year': 'category', 
                   'STEM/BHASE': 'category', 
                   'Institution': 'category', 
                   'CMAPUID': 'category', 
                   'CSDUID': 'category'})
    )
    df_clean['GRAD/ENROLL'] = df_clean['STEM/BHASE'].str.replace("^[^_]+_[^_]+_([^_]+)_.*$", lambda match: match.group(1), regex=True)
    df_clean['GEO'] = df_clean['STEM/BHASE'].str.replace(".*_([^_]*)$", lambda match: match.group(1), regex=True)
    df_clean['STEM/BHASE'] = (df_clean['STEM/BHASE']
                        .str.replace("^BHASE\\w+?$", "BHASE", case=False, regex=True)
                        .str.replace("^STEM\\w+?$", "STEM", case=False, regex=True)
    )
    df_clean['Value'] = df_clean['Value'].replace("..", np.nan).astype('float').astype('Int32')

    return df_clean

gen_df_clean = clean_data(gen_df)
gen_df_clean
# Out:
# C:\Users\SamuelMorency\AppData\Local\Temp\ipykernel_16788\3840372914.py:27: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_clean['Value'] = df_clean['Value'].replace("..", np.nan).astype('float').astype('Int32')
#                      ISCED Level of Education  \
# 0       Post-secondary non-tertiary education
# 1       Post-secondary non-tertiary education
# 2       Post-secondary non-tertiary education
# 3       Post-secondary non-tertiary education
# 4       Post-secondary non-tertiary education
# ...                                       ...
# 481949               Bachelor’s or equivalent
# 481950               Bachelor’s or equivalent
# 481951               Bachelor’s or equivalent
# 481952               Bachelor’s or equivalent
# 481953                 Master’s or equivalent
#
#                           Credential Type  \
# 0                             Certificate
# 1                             Certificate
# 2                             Certificate
# 3                             Certificate
# 4                             Certificate
# ...                                   ...
# 481949  Degree  (includes applied degree)
# 481950  Degree  (includes applied degree)
# 481951  Degree  (includes applied degree)
# 481952  Degree  (includes applied degree)
# 481953  Degree  (includes applied degree)
#
#                                                  CIP Name PR code  \
# 0                    Hair styling/stylist and hair design      10
# 1       Cooking and related culinary arts, general (ex...      10
# 2                Baking and pastry arts/baker/pastry chef      10
# 3                           Child care provider/assistant      10
# 4       Pre-technology education/pre-industrial arts p...      10
# ...                                                   ...     ...
# 481949                     Public administration, general      60
# 481950                               Social work, general      60
# 481951    Business administration and management, general      60
# 481952                                 Education, general      60
# 481953                     Public administration, general      60
#
#             PRDGUID Academic Year  Value STEM/BHASE Institution CMAPUID  \
# 0       2021A000210     2019_2020   <NA>      BHASE         NaN     NaN
# 1       2021A000210     2019_2020     42      BHASE         NaN     NaN
# 2       2021A000210     2019_2020      3      BHASE         NaN     NaN
# 3       2021A000210     2019_2020      3      BHASE         NaN     NaN
# 4       2021A000210     2019_2020      9      BHASE         NaN     NaN
# ...             ...           ...    ...        ...         ...     ...
# 481949  2021A000260     2022_2023      0      BHASE         NaN     NaN
# 481950  2021A000260     2022_2023      9      BHASE         NaN     NaN
# 481951  2021A000260     2022_2023      0      BHASE         NaN     NaN
# 481952  2021A000260     2022_2023      9      BHASE         NaN     NaN
# 481953  2021A000260     2022_2023      0      BHASE         NaN     NaN
#
#        CSDUID GRAD/ENROLL   GEO
# 0         NaN      ENROLL  PROV
# 1         NaN      ENROLL  PROV
# 2         NaN      ENROLL  PROV
# 3         NaN      ENROLL  PROV
# 4         NaN      ENROLL  PROV
# ...       ...         ...   ...
# 481949    NaN        GRAD  PROV
# 481950    NaN        GRAD  PROV
# 481951    NaN        GRAD  PROV
# 481952    NaN        GRAD  PROV
# 481953    NaN        GRAD  PROV
#
# [481954 rows x 13 columns]

# %%
# Filter out rows with 'GRAD/ENROLL' as 'ENROLL'
gen_df_grads = gen_df_clean[gen_df_clean['GRAD/ENROLL'] == 'GRAD'].drop(columns=['GRAD/ENROLL'])
gen_df_grads = gen_df_grads[gen_df_grads['CMAPUID'] != 'Z_Non-CMACA']
gen_df_grads.reset_index(drop=True, inplace=True)
gen_df_grads
# Out:
#                      ISCED Level of Education  \
# 0       Post-secondary non-tertiary education
# 1       Post-secondary non-tertiary education
# 2       Post-secondary non-tertiary education
# 3       Post-secondary non-tertiary education
# 4       Post-secondary non-tertiary education
# ...                                       ...
# 208717               Bachelor’s or equivalent
# 208718               Bachelor’s or equivalent
# 208719               Bachelor’s or equivalent
# 208720               Bachelor’s or equivalent
# 208721                 Master’s or equivalent
#
#                           Credential Type  \
# 0                             Certificate
# 1                             Certificate
# 2                             Certificate
# 3                             Certificate
# 4                             Certificate
# ...                                   ...
# 208717  Degree  (includes applied degree)
# 208718  Degree  (includes applied degree)
# 208719  Degree  (includes applied degree)
# 208720  Degree  (includes applied degree)
# 208721  Degree  (includes applied degree)
#
#                                                  CIP Name PR code  \
# 0                    Hair styling/stylist and hair design      10
# 1       Cooking and related culinary arts, general (ex...      10
# 2                Baking and pastry arts/baker/pastry chef      10
# 3       Pre-technology education/pre-industrial arts p...      10
# 4                                     Carpentry/carpenter      10
# ...                                                   ...     ...
# 208717                     Public administration, general      60
# 208718                               Social work, general      60
# 208719    Business administration and management, general      60
# 208720                                 Education, general      60
# 208721                     Public administration, general      60
#
#             PRDGUID Academic Year  Value STEM/BHASE Institution CMAPUID  \
# 0       2021A000210     2019_2020   <NA>      BHASE         NaN     NaN
# 1       2021A000210     2019_2020     30      BHASE         NaN     NaN
# 2       2021A000210     2019_2020   <NA>      BHASE         NaN     NaN
# 3       2021A000210     2019_2020   <NA>      BHASE         NaN     NaN
# 4       2021A000210     2019_2020     24      BHASE         NaN     NaN
# ...             ...           ...    ...        ...         ...     ...
# 208717  2021A000260     2022_2023      0      BHASE         NaN     NaN
# 208718  2021A000260     2022_2023      9      BHASE         NaN     NaN
# 208719  2021A000260     2022_2023      0      BHASE         NaN     NaN
# 208720  2021A000260     2022_2023      9      BHASE         NaN     NaN
# 208721  2021A000260     2022_2023      0      BHASE         NaN     NaN
#
#        CSDUID   GEO
# 0         NaN  PROV
# 1         NaN  PROV
# 2         NaN  PROV
# 3         NaN  PROV
# 4         NaN  PROV
# ...       ...   ...
# 208717    NaN  PROV
# 208718    NaN  PROV
# 208719    NaN  PROV
# 208720    NaN  PROV
# 208721    NaN  PROV
#
# [208722 rows x 12 columns]

# %%
gen_level = (gen_df_clean
             .groupby("ISCED Level of Education")
             .agg(graduates=('Value', 'sum'))
             .reset_index()
)
gen_level
# Out:
# C:\Users\SamuelMorency\AppData\Local\Temp\ipykernel_16788\2906797122.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   .groupby("ISCED Level of Education")
#                 ISCED Level of Education  graduates
# 0               Bachelor’s or equivalent   10466484
# 1                 Doctoral or equivalent     526050
# 2                 Master’s or equivalent    2307081
# 3                         Not applicable     561906
# 4  Post-secondary non-tertiary education    2511483
# 5         Short-cycle tertiary education    4979268
# 6              Upper secondary education     195384

# %%
data = pd.read_pickle("cleaned_data.pkl")
data
# Out:
#       STEM/BHASE Province_Territory      CMA_CA           Institution  \
# 0          BHASE            Alberta   Athabasca  Athabasca University
# 1          BHASE            Alberta   Athabasca  Athabasca University
# 2          BHASE            Alberta   Athabasca  Athabasca University
# 3          BHASE            Alberta   Athabasca  Athabasca University
# 4          BHASE            Alberta   Athabasca  Athabasca University
# ...          ...                ...         ...                   ...
# 53306       STEM              Yukon  Whitehorse         Yukon College
# 53307       STEM              Yukon  Whitehorse     Yukon University
# 53308       STEM              Yukon  Whitehorse     Yukon University
# 53309       STEM              Yukon  Whitehorse     Yukon University
# 53310       STEM              Yukon  Whitehorse     Yukon University
#
#              ISCED_level_of_education                    Credential_Type  \
# 0            Bachelor’s or equivalent                        Certificate
# 1            Bachelor’s or equivalent                        Certificate
# 2            Bachelor’s or equivalent                        Certificate
# 3            Bachelor’s or equivalent  Degree  (includes applied degree)
# 4            Bachelor’s or equivalent  Degree  (includes applied degree)
# ...                               ...                                ...
# 53306  Short-cycle tertiary education                            Diploma
# 53307        Bachelor’s or equivalent  Degree  (includes applied degree)
# 53308  Short-cycle tertiary education                        Certificate
# 53309  Short-cycle tertiary education                            Diploma
# 53310  Short-cycle tertiary education                            Diploma
#
#        CIP6_Code                                           CIP_Name  \
# 0        13.1007  Education/teaching of individuals with multipl...
# 1        13.1007  Education/teaching of individuals with multipl...
# 2        13.1007  Education/teaching of individuals with multipl...
# 3         4.0201  Architecture (BArch, BA, BS, BSc, MArch, MA, M...
# 4         4.0201  Architecture (BArch, BA, BS, BSc, MArch, MA, M...
# ...          ...                                                ...
# 53306    30.0101                   Biological and physical sciences
# 53307    30.0101                   Biological and physical sciences
# 53308    30.0101                   Biological and physical sciences
# 53309    15.9999  Engineering technologies and engineering-relat...
# 53310    30.0101                   Biological and physical sciences
#
#                   DGUID       year  value
# 0      2021A00054813048  2019_2020      6
# 1      2021A00054813048  2020_2021     15
# 2      2021A00054813048  2021_2022      6
# 3      2021A00054813048  2019_2020      3
# 4      2021A00054813048  2020_2021      0
# ...                 ...        ...    ...
# 53306      2021S0504990  2020_2021      3
# 53307      2021S0504990  2021_2022      6
# 53308      2021S0504990  2021_2022      3
# 53309      2021S0504990  2021_2022      0
# 53310      2021S0504990  2021_2022      0
#
# [53311 rows x 11 columns]

# %%
cma_shape = gpd.read_file("lcma000b21a_e.zip")
#cma_shape.set_index('CMAUID', inplace=True)
cma_shape
# Out:
#     CMAUID CMAPUID         DGUID DGUIDP              CMANAME CMATYPE  \
# 0      001   10001  2021S0503001   None           St. John's       B
# 1      010   10010  2021S0504010   None  Grand Falls-Windsor       D
# 2      011   10011  2021S0504011   None               Gander       D
# 3      015   10015  2021S0504015   None         Corner Brook       D
# 4      105   11105  2021S0504105   None        Charlottetown       D
# ..     ...     ...           ...    ...                  ...     ...
# 151    970   59970  2021S0504970   None        Prince George       K
# 152    975   59975  2021S0504975   None         Dawson Creek       D
# 153    977   59977  2021S0504977   None        Fort St. John       D
# 154    990   60990  2021S0504990   None           Whitehorse       D
# 155    995   61995  2021S0504995   None          Yellowknife       D
#
#        LANDAREA PRUID                                           geometry
# 0      931.5637    10  MULTIPOLYGON (((8967216.191 2136402.131, 89672...
# 1       54.8429    10  POLYGON ((8715069.6 2159071.726, 8715064.097 2...
# 2     2412.6700    10  POLYGON ((8794489.877 2214683.869, 8795102.377...
# 3     1122.5751    10  POLYGON ((8595903.94 2105395.523, 8595917.629 ...
# 4     1112.4274    11  MULTIPOLYGON (((8374335.443 1629502.597, 83743...
# ..          ...   ...                                                ...
# 151  17650.9918    59  POLYGON ((4254280.463 2492465.317, 4259395.406...
# 152  11716.7959    59  POLYGON ((4499571.286 2608807.369, 4499653.889...
# 153    617.7325    59  POLYGON ((4498146.486 2631985.637, 4498362.251...
# 154   8465.2077    60  POLYGON ((4121668.466 3499718.529, 4121976.817...
# 155    103.3722    61  POLYGON ((5103227.786 3103418.451, 5102221.597...
#
# [156 rows x 9 columns]

# %%
csd_shape = gpd.read_file("lcsd000b21a_e.zip")
#csd_shape.set_index('CSDUID', inplace=True)
csd_shape
# Out:
#        CSDUID             DGUID                   CSDNAME CSDTYPE  \
# 0     1001101  2021A00051001101  Division No.  1, Subd. V     SNO
# 1     1001105  2021A00051001105       Portugal Cove South       T
# 2     1001113  2021A00051001113                 Trepassey       T
# 3     1001120  2021A00051001120               St. Shott's       T
# 4     1001124  2021A00051001124  Division No.  1, Subd. U     SNO
# ...       ...               ...                       ...     ...
# 5156  6208068  2021A00056208068               Umingmaktok     SET
# 5157  6208073  2021A00056208073             Cambridge Bay     HAM
# 5158  6208081  2021A00056208081                Gjoa Haven     HAM
# 5159  6208087  2021A00056208087                  Taloyoak     HAM
# 5160  6208098  2021A00056208098    Kitikmeot, Unorganized      NO
#
#          LANDAREA PRUID                                           geometry
# 0        870.8928    10  MULTIPOLYGON (((8991051.954 2038839.069, 89910...
# 1          1.0770    10  POLYGON ((9001504.369 2049856.597, 9001184.977...
# 2         54.2130    10  POLYGON ((8992311.551 2054468.074, 8994001.626...
# 3          1.0729    10  POLYGON ((8985240.566 2028560.54, 8984967.974 ...
# 4        742.3781    10  MULTIPOLYGON (((8995265.971 2098624.091, 89952...
# ...           ...   ...                                                ...
# 5156      99.9450    62  MULTIPOLYGON (((5544792.883 3549525.897, 55447...
# 5157     195.7789    62  MULTIPOLYGON (((5693598.966 3664907.42, 569358...
# 5158      28.5462    62  MULTIPOLYGON (((6043125.089 3568426.163, 60431...
# 5159      35.3819    62  MULTIPOLYGON (((6136803.711 3664909.323, 61367...
# 5160  431190.4566    62  MULTIPOLYGON (((5541699.5 3510034.311, 5541692...
#
# [5161 rows x 7 columns]

# %%
csd_uids = csd_shape[['CSDUID', 'DGUID']].copy().rename(columns={'CSDUID': 'GEO_UID'})
csd_uids
# Out:
#       GEO_UID             DGUID
# 0     1001101  2021A00051001101
# 1     1001105  2021A00051001105
# 2     1001113  2021A00051001113
# 3     1001120  2021A00051001120
# 4     1001124  2021A00051001124
# ...       ...               ...
# 5156  6208068  2021A00056208068
# 5157  6208073  2021A00056208073
# 5158  6208081  2021A00056208081
# 5159  6208087  2021A00056208087
# 5160  6208098  2021A00056208098
#
# [5161 rows x 2 columns]

# %%
cma_uids = cma_shape[['CMAPUID', 'DGUID']].copy().rename(columns={'CMAPUID': 'GEO_UID'})
cma_uids
# Out:
#     GEO_UID         DGUID
# 0     10001  2021S0503001
# 1     10010  2021S0504010
# 2     10011  2021S0504011
# 3     10015  2021S0504015
# 4     11105  2021S0504105
# ..      ...           ...
# 151   59970  2021S0504970
# 152   59975  2021S0504975
# 153   59977  2021S0504977
# 154   60990  2021S0504990
# 155   61995  2021S0504995
#
# [156 rows x 2 columns]

# %%
uids = pd.concat([csd_uids, cma_uids], ignore_index=True)
uids.reset_index(drop=True, inplace=True)
uids
# Out:
#       GEO_UID             DGUID
# 0     1001101  2021A00051001101
# 1     1001105  2021A00051001105
# 2     1001113  2021A00051001113
# 3     1001120  2021A00051001120
# 4     1001124  2021A00051001124
# ...       ...               ...
# 5312    59970      2021S0504970
# 5313    59975      2021S0504975
# 5314    59977      2021S0504977
# 5315    60990      2021S0504990
# 5316    61995      2021S0504995
#
# [5317 rows x 2 columns]

# %%
# Check data types
#print(gen_df_grads['CMAPUID'].dtype)
#print(cma_uids['CMAPUID'].dtype)
#print(csd_uids['CSDUID'].dtype)

# Convert to string if needed
gen_df_grads2 = gen_df_grads.copy()
gen_df_grads2['CMAPUID'] = gen_df_grads2['CMAPUID'].astype(str).replace('nan', pd.NA)
gen_df_grads2['CSDUID'] = gen_df_grads2['CSDUID'].astype(str).replace('nan', pd.NA)
uids['GEO_UID'] = uids['GEO_UID'].astype(str)

# Create GEO_UID based on GEO type
gen_df_grads2['GEO_UID'] = np.where(
    gen_df_grads2['GEO'] == 'NONCMA', 
    gen_df_grads2['CSDUID'],
    np.where(
        gen_df_grads2['GEO'] == 'CMA', 
        gen_df_grads2['CMAPUID'],
        pd.NA
    )
)

gen_df_grads2
# Out:
#                      ISCED Level of Education  \
# 0       Post-secondary non-tertiary education
# 1       Post-secondary non-tertiary education
# 2       Post-secondary non-tertiary education
# 3       Post-secondary non-tertiary education
# 4       Post-secondary non-tertiary education
# ...                                       ...
# 208717               Bachelor’s or equivalent
# 208718               Bachelor’s or equivalent
# 208719               Bachelor’s or equivalent
# 208720               Bachelor’s or equivalent
# 208721                 Master’s or equivalent
#
#                           Credential Type  \
# 0                             Certificate
# 1                             Certificate
# 2                             Certificate
# 3                             Certificate
# 4                             Certificate
# ...                                   ...
# 208717  Degree  (includes applied degree)
# 208718  Degree  (includes applied degree)
# 208719  Degree  (includes applied degree)
# 208720  Degree  (includes applied degree)
# 208721  Degree  (includes applied degree)
#
#                                                  CIP Name PR code  \
# 0                    Hair styling/stylist and hair design      10
# 1       Cooking and related culinary arts, general (ex...      10
# 2                Baking and pastry arts/baker/pastry chef      10
# 3       Pre-technology education/pre-industrial arts p...      10
# 4                                     Carpentry/carpenter      10
# ...                                                   ...     ...
# 208717                     Public administration, general      60
# 208718                               Social work, general      60
# 208719    Business administration and management, general      60
# 208720                                 Education, general      60
# 208721                     Public administration, general      60
#
#             PRDGUID Academic Year  Value STEM/BHASE Institution CMAPUID  \
# 0       2021A000210     2019_2020   <NA>      BHASE         NaN    <NA>
# 1       2021A000210     2019_2020     30      BHASE         NaN    <NA>
# 2       2021A000210     2019_2020   <NA>      BHASE         NaN    <NA>
# 3       2021A000210     2019_2020   <NA>      BHASE         NaN    <NA>
# 4       2021A000210     2019_2020     24      BHASE         NaN    <NA>
# ...             ...           ...    ...        ...         ...     ...
# 208717  2021A000260     2022_2023      0      BHASE         NaN    <NA>
# 208718  2021A000260     2022_2023      9      BHASE         NaN    <NA>
# 208719  2021A000260     2022_2023      0      BHASE         NaN    <NA>
# 208720  2021A000260     2022_2023      9      BHASE         NaN    <NA>
# 208721  2021A000260     2022_2023      0      BHASE         NaN    <NA>
#
#        CSDUID   GEO GEO_UID
# 0        <NA>  PROV    <NA>
# 1        <NA>  PROV    <NA>
# 2        <NA>  PROV    <NA>
# 3        <NA>  PROV    <NA>
# 4        <NA>  PROV    <NA>
# ...       ...   ...     ...
# 208717   <NA>  PROV    <NA>
# 208718   <NA>  PROV    <NA>
# 208719   <NA>  PROV    <NA>
# 208720   <NA>  PROV    <NA>
# 208721   <NA>  PROV    <NA>
#
# [208722 rows x 13 columns]

# %%
gen_df_grads_merged = pd.merge(gen_df_grads2, uids, how='left', left_on='GEO_UID', right_on='GEO_UID')
gen_df_grads_merged = gen_df_grads_merged.astype({'GEO_UID': 'category', 'DGUID': 'category'})
gen_df_grads_merged
# Out:
#                      ISCED Level of Education  \
# 0       Post-secondary non-tertiary education
# 1       Post-secondary non-tertiary education
# 2       Post-secondary non-tertiary education
# 3       Post-secondary non-tertiary education
# 4       Post-secondary non-tertiary education
# ...                                       ...
# 208717               Bachelor’s or equivalent
# 208718               Bachelor’s or equivalent
# 208719               Bachelor’s or equivalent
# 208720               Bachelor’s or equivalent
# 208721                 Master’s or equivalent
#
#                           Credential Type  \
# 0                             Certificate
# 1                             Certificate
# 2                             Certificate
# 3                             Certificate
# 4                             Certificate
# ...                                   ...
# 208717  Degree  (includes applied degree)
# 208718  Degree  (includes applied degree)
# 208719  Degree  (includes applied degree)
# 208720  Degree  (includes applied degree)
# 208721  Degree  (includes applied degree)
#
#                                                  CIP Name PR code  \
# 0                    Hair styling/stylist and hair design      10
# 1       Cooking and related culinary arts, general (ex...      10
# 2                Baking and pastry arts/baker/pastry chef      10
# 3       Pre-technology education/pre-industrial arts p...      10
# 4                                     Carpentry/carpenter      10
# ...                                                   ...     ...
# 208717                     Public administration, general      60
# 208718                               Social work, general      60
# 208719    Business administration and management, general      60
# 208720                                 Education, general      60
# 208721                     Public administration, general      60
#
#             PRDGUID Academic Year  Value STEM/BHASE Institution CMAPUID  \
# 0       2021A000210     2019_2020   <NA>      BHASE         NaN    <NA>
# 1       2021A000210     2019_2020     30      BHASE         NaN    <NA>
# 2       2021A000210     2019_2020   <NA>      BHASE         NaN    <NA>
# 3       2021A000210     2019_2020   <NA>      BHASE         NaN    <NA>
# 4       2021A000210     2019_2020     24      BHASE         NaN    <NA>
# ...             ...           ...    ...        ...         ...     ...
# 208717  2021A000260     2022_2023      0      BHASE         NaN    <NA>
# 208718  2021A000260     2022_2023      9      BHASE         NaN    <NA>
# 208719  2021A000260     2022_2023      0      BHASE         NaN    <NA>
# 208720  2021A000260     2022_2023      9      BHASE         NaN    <NA>
# 208721  2021A000260     2022_2023      0      BHASE         NaN    <NA>
#
#        CSDUID   GEO GEO_UID DGUID
# 0        <NA>  PROV     NaN   NaN
# 1        <NA>  PROV     NaN   NaN
# 2        <NA>  PROV     NaN   NaN
# 3        <NA>  PROV     NaN   NaN
# 4        <NA>  PROV     NaN   NaN
# ...       ...   ...     ...   ...
# 208717   <NA>  PROV     NaN   NaN
# 208718   <NA>  PROV     NaN   NaN
# 208719   <NA>  PROV     NaN   NaN
# 208720   <NA>  PROV     NaN   NaN
# 208721   <NA>  PROV     NaN   NaN
#
# [208722 rows x 14 columns]
